# %%
def displayOuterlayerInterface():
    # Define colors using ANSI escape codes
    RED = "\033[31m"
    GREEN = "\033[32m"
    YELLOW = "\033[33m"
    BLUE = "\033[34m"
    RESET = "\033[0m"

    # Outer layer (colored flaps)
    print(f" _______________________ {RESET}")
    print(f"| {GREEN} _______     {RED}_______{RESET}  |")
    print(f"| {GREEN}|       {GREEN}|   {RED}|       {RED}|{RESET} |")
    print(f"| {GREEN}| GREEN {GREEN}|   {RED}|  RED  {RED}|{RESET} |")
    print(f"| {GREEN}|_______{GREEN}|   {RED}|_______{RED}|{RESET} |")  # Innermost layer (where the fortune will be)
    print(f"| {RESET}                      |")
    print(f"| {BLUE} _______     {YELLOW}_______{RESET}  |")
    print(f"| {BLUE}|       {BLUE}|   {YELLOW}|       {YELLOW}|{RESET} |")
    print(f"| {BLUE}| BLUE  {BLUE}|   {YELLOW}| YELLOW{YELLOW}|{RESET} |")
    print(f"| {BLUE}|_______{BLUE}|   {YELLOW}|_______{YELLOW}|{RESET} |")
    print(f"|_______________________{RESET}|")

def displayOddlayerInterface():
    # Define colors using ANSI escape codes
    RED = "\033[31m"
    GREEN = "\033[32m"
    YELLOW = "\033[33m"
    BLUE = "\033[34m"
    RESET = "\033[0m"

    # Outer layer (colored flaps)
    print(f" _______________________ {RESET}")
    print(f"| {GREEN} _______     {RED}_______{RESET}  |")
    print(f"| {GREEN}|       {GREEN}|   {RED}|       {RED}|{RESET} |")
    print(f"| {GREEN}|   1   {GREEN}|   {RED}|   3   {RED}|{RESET} |")
    print(f"| {GREEN}|_______{GREEN}|   {RED}|_______{RED}|{RESET} |")  # Innermost layer (where the fortune will be)
    print(f"| {RESET}                      |")
    print(f"| {BLUE} _______     {YELLOW}_______{RESET}  |")
    print(f"| {BLUE}|       {BLUE}|   {YELLOW}|       {YELLOW}|{RESET} |")
    print(f"| {BLUE}|   5   {BLUE}|   {YELLOW}|   7   {YELLOW}|{RESET} |")
    print(f"| {BLUE}|_______{BLUE}|   {YELLOW}|_______{YELLOW}|{RESET} |")
    print(f"|_______________________{RESET}|")

def displayEvenlayerInterface():
    # Define colors using ANSI escape codes
    RED = "\033[31m"
    GREEN = "\033[32m"
    YELLOW = "\033[33m"
    BLUE = "\033[34m"
    RESET = "\033[0m"

    # Outer layer (colored flaps)
    print(f" _______________________ {RESET}")
    print(f"| {GREEN} _______     {RED}_______{RESET}  |")
    print(f"| {GREEN}|       {GREEN}|   {RED}|       {RED}|{RESET} |")
    print(f"| {GREEN}|   2   {GREEN}|   {RED}|   4   {RED}|{RESET} |")
    print(f"| {GREEN}|_______{GREEN}|   {RED}|_______{RED}|{RESET} |")  # Innermost layer (where the fortune will be)
    print(f"| {RESET}                      |")
    print(f"| {BLUE} _______     {YELLOW}_______{RESET}  |")
    print(f"| {BLUE}|       {BLUE}|   {YELLOW}|       {YELLOW}|{RESET} |")
    print(f"| {BLUE}|   6   {BLUE}|   {YELLOW}|   8   {YELLOW}|{RESET} |")
    print(f"| {BLUE}|_______{BLUE}|   {YELLOW}|_______{YELLOW}|{RESET} |")
    print(f"|_______________________{RESET}|")

# %%
def displayNum(colour):
    odd = [1,3,5,7]
    even = [2,4,6,8]
    existColour = ["GREEN","YELLOW","BLUE","RED"]
    if colour in existColour:
        if len(colour) in odd:
            displayOddlayerInterface()
        elif len(colour) in even:
            displayEvenlayerInterface()
        else:
            raise Exception("Incorrect Number chosen")
    else:
        raise Exception("Incorrect Colour chosen")

# %%
def printContentsLayer(num):
    import time
    contents = {
    1: "Why don't scientists trust atoms? Because they make up everything!",
    2: "I told my wife she was drawing her eyebrows too high. She looked surprised.",
    3: "Parallel lines have so much in common. It's a shame they'll never meet.",
    4: "I used to play piano by ear, but now I use my hands.",
    5: "My dog used to chase people on a bike a lot. It got so bad I had to take his bike away.",
    6: "I'm reading a book about anti-gravity. It's impossible to put down!",
    7: "I'm on a seafood diet. I see food and I eat it.",
    8: "I asked my dad for a loan and he said, 'Sure, as long as you pay me back with interest.' I said, 'That's cool, I'll write you a letter when I get back.'"
    }
    print("YOU GOT\n")
    print(".\n")
    time.sleep(1)
    print(".\n")
    time.sleep(1)
    print(".\n")
    time.sleep(1)
    print(contents[num])

# %%
import cProfile
def main():
    print("Welcome to Tip Top !")
    displayOuterlayerInterface()
    chosen_colour = input("Enter the colour to be chosen :")
    displayNum(chosen_colour)
    chosen_number = int(input("Enter the number to be chosen :"))
    print("\n")
    printContentsLayer(chosen_number)
cProfile.run('main()')
# Out:
# Welcome to Tip Top !
#  _______________________
# |  _______     _______  |
# | |       |   |       | |
# | | GREEN |   |  RED  | |
# | |_______|   |_______| |
# |                       |
# |  _______     _______  |
# | |       |   |       | |
# | | BLUE  |   | YELLOW| |
# | |_______|   |_______| |
# |_______________________|
# Enter the colour to be chosen : RED
#  _______________________
# |  _______     _______  |
# | |       |   |       | |
# | |   1   |   |   3   | |
# | |_______|   |_______| |
# |                       |
# |  _______     _______  |
# | |       |   |       | |
# | |   5   |   |   7   | |
# | |_______|   |_______| |
# |_______________________|
# Enter the number to be chosen : 1
# YOU GOT
#
# .
#
# .
#
# .
#
# Why don't scientists trust atoms? Because they make up everything!
#          12308 function calls (12284 primitive calls) in 12.943 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    3.003    3.003 1518200348.py:1(printContentsLayer)
#         1    0.000    0.000    0.000    0.000 28236817.py:1(displayOuterlayerInterface)
#         1    0.000    0.000    0.001    0.001 28236817.py:22(displayOddlayerInterface)
#         1    0.000    0.000    0.001    0.001 4103307734.py:1(displayNum)
#         1    0.000    0.000   12.943   12.943 450647760.py:2(main)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:405(parent)
#         1    0.000    0.000   12.943   12.943 <string>:1(<module>)
#         8    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         8    0.000    0.000    0.000    0.000 __init__.py:299(loads)
#         8    0.000    0.000    0.000    0.000 _parser.py:1006(_find_hms_idx)
#         8    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         8    0.000    0.000    0.000    0.000 _parser.py:1061(<genexpr>)
#         4    0.000    0.000    0.000    0.000 _parser.py:1099(_parse_min_sec)
#         4    0.000    0.000    0.000    0.000 _parser.py:1133(_parsems)
#        12    0.000    0.000    0.000    0.000 _parser.py:1141(_to_decimal)
#         4    0.000    0.000    0.000    0.000 _parser.py:1177(_build_tzaware)
#         4    0.000    0.000    0.000    0.000 _parser.py:1217(_build_naive)
#         4    0.000    0.000    0.003    0.001 _parser.py:1270(parse)
#         4    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#        52    0.000    0.000    0.001    0.000 _parser.py:189(__next__)
#         4    0.000    0.000    0.001    0.000 _parser.py:199(split)
#        56    0.000    0.000    0.000    0.000 _parser.py:203(isword)
#       118    0.000    0.000    0.000    0.000 _parser.py:208(isnum)
#        16    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#         4    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#         4    0.000    0.000    0.000    0.000 _parser.py:233(__len__)
#        52    0.000    0.000    0.000    0.000 _parser.py:234(<genexpr>)
#         8    0.000    0.000    0.000    0.000 _parser.py:319(jump)
#         8    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#        12    0.000    0.000    0.000    0.000 _parser.py:329(month)
#        12    0.000    0.000    0.000    0.000 _parser.py:336(hms)
#         8    0.000    0.000    0.000    0.000 _parser.py:342(ampm)
#         4    0.000    0.000    0.000    0.000 _parser.py:354(tzoffset)
#         4    0.000    0.000    0.000    0.000 _parser.py:360(convertyear)
#         4    0.000    0.000    0.000    0.000 _parser.py:380(validate)
#         4    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#         4    0.000    0.000    0.000    0.000 _parser.py:402(has_year)
#        12    0.000    0.000    0.000    0.000 _parser.py:428(append)
#         4    0.000    0.000    0.000    0.000 _parser.py:474(resolve_ymd)
#         4    0.000    0.000    0.000    0.000 _parser.py:482(<dictcomp>)
#         4    0.000    0.000    0.002    0.001 _parser.py:572(parse)
#         4    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#         4    0.000    0.000    0.002    0.000 _parser.py:666(_parse)
#        52    0.000    0.000    0.001    0.000 _parser.py:77(get_token)
#         8    0.000    0.000    0.000    0.000 _parser.py:875(_parse_numeric_token)
#         2    0.000    0.000    0.000    0.000 adapter.py:393(adapt)
#         8    0.000    0.000    0.000    0.000 decoder.py:332(decode)
#         8    0.000    0.000    0.000    0.000 decoder.py:343(raw_decode)
#         8    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         8    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#         8    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#      1288    0.005    0.000    0.005    0.000 enum.py:1093(__new__)
#         3    0.000    0.000    0.000    0.000 enum.py:117(_iter_bits_lsb)
#         3    0.000    0.000    0.000    0.000 enum.py:1355(_iter_member_by_value_)
#         1    0.000    0.000    0.000    0.000 enum.py:1375(_missing_)
#         1    0.000    0.000    0.000    0.000 enum.py:1451(<listcomp>)
#      1268    0.015    0.000    0.032    0.000 enum.py:1505(__or__)
#         6    0.000    0.000    0.000    0.000 enum.py:1515(__and__)
#      1288    0.008    0.000    0.013    0.000 enum.py:686(__call__)
#         2    0.000    0.000    0.000    0.000 error.py:103(__init__)
#         2    0.000    0.000    0.000    0.000 error.py:28(__init__)
#        16    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         4    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         4    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         4    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#        14    0.000    0.000    0.000    0.000 iostream.py:137(_event_pipe)
#        14    0.000    0.000    0.001    0.000 iostream.py:258(schedule)
#        58    0.000    0.000    0.000    0.000 iostream.py:519(_is_master_process)
#        58    0.000    0.000    0.001    0.000 iostream.py:546(_schedule_flush)
#         4    0.000    0.000    0.006    0.002 iostream.py:561(flush)
#        58    0.001    0.000    0.002    0.000 iostream.py:624(write)
#         4    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         8    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#        24    0.000    0.000    0.003    0.000 jsonutil.py:54(parse_date)
#      28/4    0.000    0.000    0.003    0.001 jsonutil.py:70(extract_dates)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:77(json_clean)
#         2    0.000    0.000    9.939    4.969 kernelbase.py:1252(raw_input)
#         2    0.022    0.011    9.939    4.969 kernelbase.py:1269(_input_request)
#         2    0.000    0.000    0.000    0.000 kernelbase.py:644(get_parent)
#       628    9.861    0.016    9.894    0.016 poll.py:107(select)
#         2    0.000    0.000    0.004    0.002 session.py:1022(deserialize)
#         2    0.000    0.000    0.000    0.000 session.py:1088(<listcomp>)
#         8    0.000    0.000    0.000    0.000 session.py:120(json_unpacker)
#         2    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         2    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         2    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         2    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         2    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         2    0.000    0.000    0.000    0.000 session.py:649(msg)
#         4    0.000    0.000    0.000    0.000 session.py:675(sign)
#         2    0.000    0.000    0.001    0.000 session.py:690(serialize)
#         2    0.000    0.000    0.001    0.001 session.py:754(send)
#         2    0.000    0.000    0.000    0.000 session.py:854(<listcomp>)
#         2    0.000    0.000    0.004    0.002 session.py:913(recv)
#         8    0.000    0.000    0.001    0.000 session.py:92(json_packer)
#         2    0.000    0.000    0.000    0.000 session.py:956(feed_identities)
#         2    0.000    0.000    0.000    0.000 session.py:998(_add_digest)
#        28    0.001    0.000    0.001    0.000 socket.py:621(send)
#         2    0.000    0.000    0.000    0.000 socket.py:698(send_multipart)
#         4    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#        18    0.000    0.000    0.000    0.000 threading.py:1125(_wait_for_tstate_lock)
#         8    0.000    0.000    0.000    0.000 threading.py:1168(ident)
#        18    0.000    0.000    0.000    0.000 threading.py:1192(is_alive)
#         4    0.000    0.000    0.000    0.000 threading.py:1453(current_thread)
#         4    0.000    0.000    0.000    0.000 threading.py:243(__init__)
#         4    0.000    0.000    0.000    0.000 threading.py:271(__enter__)
#         4    0.000    0.000    0.000    0.000 threading.py:274(__exit__)
#         4    0.000    0.000    0.000    0.000 threading.py:280(_release_save)
#         4    0.000    0.000    0.000    0.000 threading.py:283(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 threading.py:286(_is_owned)
#         4    0.000    0.000    0.006    0.001 threading.py:295(wait)
#         4    0.000    0.000    0.000    0.000 threading.py:562(__init__)
#        18    0.000    0.000    0.000    0.000 threading.py:575(is_set)
#         4    0.000    0.000    0.006    0.001 threading.py:611(wait)
#      1330    0.005    0.000    0.005    0.000 traitlets.py:651(get)
#      1330    0.006    0.000    0.010    0.000 traitlets.py:689(__get__)
#         4    0.000    0.000    0.000    0.000 typing.py:1378(__hash__)
#         6    0.000    0.000    0.000    0.000 typing.py:2268(cast)
#        10    0.000    0.000    0.000    0.000 typing.py:359(inner)
#         2    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         5    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFD6CC4C4D0}
#         2    0.000    0.000    0.000    0.000 {built-in method _hashlib.compare_digest}
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         4    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   12.943   12.943 {built-in method builtins.exec}
#        76    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      2139    0.005    0.000    0.005    0.000 {built-in method builtins.isinstance}
#       165    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        29    0.000    0.000    0.002    0.000 {built-in method builtins.print}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         6    0.000    0.000    0.000    0.000 {built-in method now}
#        62    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         3    3.002    1.001    3.002    1.001 {built-in method time.sleep}
#         4    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        58    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        34    0.006    0.000    0.006    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        18    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       692    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'count' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        12    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#         6    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#        56    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#       134    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        16    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#        48    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        28    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       106    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        12    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#         4    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        16    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#        58    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
School_schedule = {
    "Monday": ["Math", "Science", "English"],
    "Tuesday": ["History", "Math", "Art"],
    "Wednesday": ["Science", "English", "PE"],
    "Thursday": ["Math", "History", "Art"],
    "Friday": ["Science", "English", "PE"]
}
print(School_schedule.get("Monday",[]))  # Handle case where day might not be present
# Out:
# ['Math', 'Science', 'English']
